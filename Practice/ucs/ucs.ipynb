# %%
class GRAPH:
    def __init__(self):
        self.graph = {}
    
    def add_node(self, node):
        if node not in self.graph:
            self.graph[node] = {}
            print("Node added: ", node, "graph: ", self.graph)
        else:
            print("Node already exists: ", node, "graph: ", self.graph)

    def add_edge(self, source_node, target_node, weight):
        self.add_node(source_node)
        self.add_node(target_node)
        self.graph[source_node][target_node] = weight
        self.graph[target_node][source_node] = weight
        print("Edge added: ", source_node, " - ", target_node, " with weight: ", weight, "graph: ", self.graph)
    
    def reheapup(self, heap):
        current_index = len(heap) - 1
        while current_index > 0:
            parent_index = (current_index - 1) // 2
            if heap[current_index][0] < heap[parent_index][0]:
                #swap
                heap[current_index], heap[parent_index] = heap[parent_index], heap[current_index]
            else:
                #nouthing to swap
                break
            current_index = parent_index
            
    def reheapdown(self, heap):
        current_index = 0
        left_child_index = 2 * current_index + 1
        right_child_index = 2 * current_index + 2

        small = 0
        while(True):
            if left_child_index < len(heap) and heap[left_child_index] < heap[small]:
                small = left_child_index
            
            if right_child_index < len(heap) and heap[right_child_index] < heap[small]:
                small = right_child_index

            if small != current_index:
                #swap
                heap[current_index], heap[small] = heap[small], heap[current_index]
                current_index = small
            
            else: 
                break

    def popp(self, heap):
        if len(heap) == 0:
            #The heap is empty
            return None
        if len(heap) == 1:
            #The heap has only one item
            return heap.pop()
        
        root = heap[0]
        heap[0] = heap.pop()
        self.reheapdown(heap)
        return root

    def push(self, heap, item):
        heap.append(item)
        self.reheapup(heap)      

    def ucs(self, start, end):
            pqueue = [(0, start)]
            visited = set()
            while(pqueue):
                print("In the loop of pqueue", pqueue)
                current_cost, current_node = self.popp(pqueue)
                if current_node == end:
                    return current_cost
                if current_node in visited:
                    print("Node already visited: ", current_node, " with cost: ", current_cost, "visited set:", visited)
                    continue
                #else it will come
                if current_node not in visited:
                    print("Visiting node: ", current_node, " with cost: ", current_cost)
                    visited.add(current_node)
                    for neighbor, weight in self.graph[current_node].items():
                        if neighbor not in visited:
                            self.push(pqueue, (current_cost + weight, neighbor))

# %%
weighted_graph = GRAPH()
       # Add nodes
weighted_graph.add_node('A')
weighted_graph.add_node('B')
weighted_graph.add_node('C')
weighted_graph.add_node('D')

    # Add edges with weights
weighted_graph.add_edge('A', 'B', 3)
weighted_graph.add_edge('A', 'C', 2)
weighted_graph.add_edge('B', 'D', 1)
weighted_graph.add_edge('C', 'D', 4)

    # Perform UCS
start_node = 'A'
goal_node = 'D'
result = weighted_graph.ucs(start_node, goal_node)
print(result)
# Out:
# Node added:  A graph:  {'A': {}}
# Node added:  B graph:  {'A': {}, 'B': {}}
# Node added:  C graph:  {'A': {}, 'B': {}, 'C': {}}
# Node added:  D graph:  {'A': {}, 'B': {}, 'C': {}, 'D': {}}
# Node already exists:  A graph:  {'A': {}, 'B': {}, 'C': {}, 'D': {}}
# Node already exists:  B graph:  {'A': {}, 'B': {}, 'C': {}, 'D': {}}
# Edge added:  A  -  B  with weight:  3 graph:  {'A': {'B': 3}, 'B': {'A': 3}, 'C': {}, 'D': {}}
# Node already exists:  A graph:  {'A': {'B': 3}, 'B': {'A': 3}, 'C': {}, 'D': {}}
# Node already exists:  C graph:  {'A': {'B': 3}, 'B': {'A': 3}, 'C': {}, 'D': {}}
# Edge added:  A  -  C  with weight:  2 graph:  {'A': {'B': 3, 'C': 2}, 'B': {'A': 3}, 'C': {'A': 2}, 'D': {}}
# Node already exists:  B graph:  {'A': {'B': 3, 'C': 2}, 'B': {'A': 3}, 'C': {'A': 2}, 'D': {}}
# Node already exists:  D graph:  {'A': {'B': 3, 'C': 2}, 'B': {'A': 3}, 'C': {'A': 2}, 'D': {}}
# Edge added:  B  -  D  with weight:  1 graph:  {'A': {'B': 3, 'C': 2}, 'B': {'A': 3, 'D': 1}, 'C': {'A': 2}, 'D': {'B': 1}}
# Node already exists:  C graph:  {'A': {'B': 3, 'C': 2}, 'B': {'A': 3, 'D': 1}, 'C': {'A': 2}, 'D': {'B': 1}}
# Node already exists:  D graph:  {'A': {'B': 3, 'C': 2}, 'B': {'A': 3, 'D': 1}, 'C': {'A': 2}, 'D': {'B': 1}}
# Edge added:  C  -  D  with weight:  4 graph:  {'A': {'B': 3, 'C': 2}, 'B': {'A': 3, 'D': 1}, 'C': {'A': 2, 'D': 4}, 'D': {'B': 1, 'C': 4}}
# In the loop of pqueue [(0, 'A')]
# Visiting node:  A  with cost:  0
# In the loop of pqueue [(2, 'C'), (3, 'B')]
# Visiting node:  C  with cost:  2
# In the loop of pqueue [(3, 'B'), (6, 'D')]
# Visiting node:  B  with cost:  3
# In the loop of pqueue [(4, 'D'), (6, 'D')]
# 4

# %%
weighted_graph = GRAPH()
       # Add nodes
weighted_graph.add_node('A')
weighted_graph.add_node('B')
weighted_graph.add_node('C')
weighted_graph.add_node('D')
weighted_graph.add_node('E')
weighted_graph.add_node('F')


    # Add edges with weights
weighted_graph.add_edge('A', 'B', 3)
weighted_graph.add_edge('A', 'C', 2)
weighted_graph.add_edge('B', 'D', 1)
weighted_graph.add_edge('C', 'D', 4)
weighted_graph.add_edge('B', 'E', 5)
weighted_graph.add_edge('D', 'F', 4)
weighted_graph.add_edge('E', 'F', 2)

    # Perform UCS
start_node = 'A'
goal_node = 'F'
result = weighted_graph.ucs(start_node, goal_node)
print(result)
# Out:
# Node added:  A graph:  {'A': {}}
# Node added:  B graph:  {'A': {}, 'B': {}}
# Node added:  C graph:  {'A': {}, 'B': {}, 'C': {}}
# Node added:  D graph:  {'A': {}, 'B': {}, 'C': {}, 'D': {}}
# Node added:  E graph:  {'A': {}, 'B': {}, 'C': {}, 'D': {}, 'E': {}}
# Node added:  F graph:  {'A': {}, 'B': {}, 'C': {}, 'D': {}, 'E': {}, 'F': {}}
# Node already exists:  A graph:  {'A': {}, 'B': {}, 'C': {}, 'D': {}, 'E': {}, 'F': {}}
# Node already exists:  B graph:  {'A': {}, 'B': {}, 'C': {}, 'D': {}, 'E': {}, 'F': {}}
# Edge added:  A  -  B  with weight:  3 graph:  {'A': {'B': 3}, 'B': {'A': 3}, 'C': {}, 'D': {}, 'E': {}, 'F': {}}
# Node already exists:  A graph:  {'A': {'B': 3}, 'B': {'A': 3}, 'C': {}, 'D': {}, 'E': {}, 'F': {}}
# Node already exists:  C graph:  {'A': {'B': 3}, 'B': {'A': 3}, 'C': {}, 'D': {}, 'E': {}, 'F': {}}
# Edge added:  A  -  C  with weight:  2 graph:  {'A': {'B': 3, 'C': 2}, 'B': {'A': 3}, 'C': {'A': 2}, 'D': {}, 'E': {}, 'F': {}}
# Node already exists:  B graph:  {'A': {'B': 3, 'C': 2}, 'B': {'A': 3}, 'C': {'A': 2}, 'D': {}, 'E': {}, 'F': {}}
# Node already exists:  D graph:  {'A': {'B': 3, 'C': 2}, 'B': {'A': 3}, 'C': {'A': 2}, 'D': {}, 'E': {}, 'F': {}}
# Edge added:  B  -  D  with weight:  1 graph:  {'A': {'B': 3, 'C': 2}, 'B': {'A': 3, 'D': 1}, 'C': {'A': 2}, 'D': {'B': 1}, 'E': {}, 'F': {}}
# Node already exists:  C graph:  {'A': {'B': 3, 'C': 2}, 'B': {'A': 3, 'D': 1}, 'C': {'A': 2}, 'D': {'B': 1}, 'E': {}, 'F': {}}
# Node already exists:  D graph:  {'A': {'B': 3, 'C': 2}, 'B': {'A': 3, 'D': 1}, 'C': {'A': 2}, 'D': {'B': 1}, 'E': {}, 'F': {}}
# Edge added:  C  -  D  with weight:  4 graph:  {'A': {'B': 3, 'C': 2}, 'B': {'A': 3, 'D': 1}, 'C': {'A': 2, 'D': 4}, 'D': {'B': 1, 'C': 4}, 'E': {}, 'F': {}}
# Node already exists:  B graph:  {'A': {'B': 3, 'C': 2}, 'B': {'A': 3, 'D': 1}, 'C': {'A': 2, 'D': 4}, 'D': {'B': 1, 'C': 4}, 'E': {}, 'F': {}}
# Node already exists:  E graph:  {'A': {'B': 3, 'C': 2}, 'B': {'A': 3, 'D': 1}, 'C': {'A': 2, 'D': 4}, 'D': {'B': 1, 'C': 4}, 'E': {}, 'F': {}}
# Edge added:  B  -  E  with weight:  5 graph:  {'A': {'B': 3, 'C': 2}, 'B': {'A': 3, 'D': 1, 'E': 5}, 'C': {'A': 2, 'D': 4}, 'D': {'B': 1, 'C': 4}, 'E': {'B': 5}, 'F': {}}
# Node already exists:  D graph:  {'A': {'B': 3, 'C': 2}, 'B': {'A': 3, 'D': 1, 'E': 5}, 'C': {'A': 2, 'D': 4}, 'D': {'B': 1, 'C': 4}, 'E': {'B': 5}, 'F': {}}
# Node already exists:  F graph:  {'A': {'B': 3, 'C': 2}, 'B': {'A': 3, 'D': 1, 'E': 5}, 'C': {'A': 2, 'D': 4}, 'D': {'B': 1, 'C': 4}, 'E': {'B': 5}, 'F': {}}
# Edge added:  D  -  F  with weight:  4 graph:  {'A': {'B': 3, 'C': 2}, 'B': {'A': 3, 'D': 1, 'E': 5}, 'C': {'A': 2, 'D': 4}, 'D': {'B': 1, 'C': 4, 'F': 4}, 'E': {'B': 5}, 'F': {'D': 4}}
# Node already exists:  E graph:  {'A': {'B': 3, 'C': 2}, 'B': {'A': 3, 'D': 1, 'E': 5}, 'C': {'A': 2, 'D': 4}, 'D': {'B': 1, 'C': 4, 'F': 4}, 'E': {'B': 5}, 'F': {'D': 4}}
# Node already exists:  F graph:  {'A': {'B': 3, 'C': 2}, 'B': {'A': 3, 'D': 1, 'E': 5}, 'C': {'A': 2, 'D': 4}, 'D': {'B': 1, 'C': 4, 'F': 4}, 'E': {'B': 5}, 'F': {'D': 4}}
# Edge added:  E  -  F  with weight:  2 graph:  {'A': {'B': 3, 'C': 2}, 'B': {'A': 3, 'D': 1, 'E': 5}, 'C': {'A': 2, 'D': 4}, 'D': {'B': 1, 'C': 4, 'F': 4}, 'E': {'B': 5, 'F': 2}, 'F': {'D': 4, 'E': 2}}
# In the loop of pqueue [(0, 'A')]
# Visiting node:  A  with cost:  0
# In the loop of pqueue [(2, 'C'), (3, 'B')]
# Visiting node:  C  with cost:  2
# In the loop of pqueue [(3, 'B'), (6, 'D')]
# Visiting node:  B  with cost:  3
# In the loop of pqueue [(4, 'D'), (6, 'D'), (8, 'E')]
# Visiting node:  D  with cost:  4
# In the loop of pqueue [(6, 'D'), (8, 'E'), (8, 'F')]
# Node already visited:  D  with cost:  6 visited set: {'B', 'C', 'D', 'A'}
# In the loop of pqueue [(8, 'E'), (8, 'F')]
# Visiting node:  E  with cost:  8
# In the loop of pqueue [(8, 'F'), (10, 'F')]
# 8

# %%
# weighted_graph = GRAPH()
#        # Add nodes
# weighted_graph.add_node('Oradea')
# weighted_graph.add_node('Zerind')
# weighted_graph.add_node('Arad')
# weighted_graph.add_node('Timisoara')
# weighted_graph.add_node('Sibiu')
# weighted_graph.add_node('Fagaras')
# weighted_graph.add_node('Rimnicu Vilcea')
# weighted_graph.add_node('Lugoj')
# weighted_graph.add_node('Mehadia')
# weighted_graph.add_node('Drobeta')
# weighted_graph.add_node('Craiova')
# weighted_graph.add_node('Pitesti')
# weighted_graph.add_node('Bucharest')
# weighted_graph.add_node('Giurgiu')
# weighted_graph.add_node('Urziceni')
# weighted_graph.add_node('Hirsova')
# weighted_graph.add_node('Eforie')
# weighted_graph.add_node('Vaslui')
# weighted_graph.add_node('Iasi')
# weighted_graph.add_node('Neamt')




#     # Add edges with weights
# weighted_graph.add_edge('Ordadea', 'Zerind', 71)
# weighted_graph.add_edge('Ordadea', 'Sibiu', 151)
# weighted_graph.add_edge('Zerind', 'Arad', 75)
# weighted_graph.add_edge('Arad', 'Sibiu', 140)
# weighted_graph.add_edge('Arad', 'Timisoara', 118)
# weighted_graph.add_edge('Timisoara', 'Lugoj', 111)
# weighted_graph.add_edge('Lugoj', 'Mehadia', 70)
# weighted_graph.add_edge('Mehadia', 'Drobeta', 75)
# weighted_graph.add_edge('Drobeta', 'Craiova', 120)
# weighted_graph.add_edge('Sibiu', 'Rimnicu Vilcea', 80)
# weighted_graph.add_edge('Sibiu', 'Fagaras', 99)
# weighted_graph.add_edge('Rimnicu Vilcea', 'Craiova', 146)
# weighted_graph.add_edge('Rimnicu Vilcea', 'Pitesti', 97)
# weighted_graph.add_edge('Pitesti', 'Craiova', 138)
# weighted_graph.add_edge('Pitesti', 'Bucharest', 101)
# weighted_graph.add_edge('Fagaras', 'Bucharest', 211)
# weighted_graph.add_edge('Bucharest', 'Giurgiu', 90)
# weighted_graph.add_edge('Bucharest', 'Urziceni', 85)
# weighted_graph.add_edge('Urziceni', 'Hirsova', 98)
# weighted_graph.add_edge('Hirsova', 'Eforie', 86)
# weighted_graph.add_edge('Urziceni', 'Vaslui', 142)
# weighted_graph.add_edge('Vaslui', 'Iasi', 92)
# weighted_graph.add_edge('Iasi', 'Neamt', 87)



#     # Perform UCS
# start_node = 'Arad'
# goal_node = 'Bucharest'
# result = weighted_graph.ucs(start_node, goal_node)
# print(result)
